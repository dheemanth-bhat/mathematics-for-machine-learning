# %% [markdown]
# # Intro to Hypothesis Testing

# %% [markdown]
# ## 1 Hypothesis Testing

# %% [markdown]
# ### 1.1 What is Hypothesis Testing?

# %% [markdown]
# #### Definition

# %% [markdown]
# Hypothesis Testing is a branch of Inferential Statistics that helps us in breaking down the data and take trustable decisions.

# %% [markdown]
# #### Properties

# %% [markdown]
# 1. Hypothesis Testing uses sample data as **evidence** to evaluate some **claims** made about population data and help us in taking **decisions** with some quantifiable **risk**.
# 2. Hypothesis Testing helps us in quantifying the **statistical significance** of values seen (as part of Descriptive Statistics) in the data.
# 3. In other words, for the given data, values that we see in Descriptive Statistics are statistically significant or not?
# 4. Hypothesis Testing is **not about predictions** instead it is trying to **infer** based on some evidence.

# %% [markdown]
# #### How Hypothesis Testing Works?

# %% [markdown]
# 1. Make a **claim** against existing data by opposing some default assumption.
# 2. Perform Controlled **experiment**.
# 3. **Collect** data/evidence to support the claim.
# 4. **Evaluate** the significance of the evidence, backing the claim, against default assumption.
# 5. **Conclude** the Hypothesis Test.

# %% [markdown]
# ##### Example

# %% [markdown]
# - Claim: "A new drug lowers blood pressure."
# - Experiment: Randomized and **controlled** clinical trials on volunteers.
# - Collect data: **Sampling** of Blood pressure measurements taken from volunteers.
# - Analyze: Perform a statistical test.
# - Conclusion: Determine whether the evidence supports the claim.

# %% [markdown]
# #### What are the outcomes of Hypothesis Testing?

# %% [markdown]
# - When there is **enough data or evidence** to backup the claim then the **default assumption is rejected**.
# - When the **data or evidence** backing the claim is **insignificant** we **fail to reject the default assumption**.

# %% [markdown]
# > **Note**:
# >
# > Burden of proof is on those who want to reject default assumption.

# %% [markdown]
# #### Hypothesis Testing Framework

# %% [markdown]
# Hypothesis -> Experiment (controlled) -> Handful (Sampling) -> Unbiased -> Experiment output -> Validation

# %% [markdown]
# Hypothesis Testing Framework is the process of designing some experiments, collecting data as evidence to **measure the impact** of the experiment.

# %% [markdown]
# ##### Types of Impact

# %% [markdown]
# There can be three types of impact:
#
# 1. No Impact
# 2. Positive Impact
# 3. Negative Impact
#
# Hypothesis testing tries to validate the **significance** of claimed positive or negative impact over default current state of no impact.

# %% [markdown]
# ### 1.2 Basic terminologies

# %% [markdown]
# #### Key Concepts

# %% [markdown]
# 1. Assumptions / Hypothesis
# 2. Data / Evidence to support or negate the assumption.

# %% [markdown]
# #### Types of Hypothesis

# %% [markdown]
# There are two types of Hypothesis or Assumptions:
#
# 1. Default Assumption
# 2. Claim
#
# Other terms used for Default Assumption are:
#
# 1. Null Hypothesis $H_0$
# 2. Status Quo
# 3. Baseline Assumption
#
# Other terms used for Claim are:
#
# 1. Alternate Hypothesis $H_a$ or $H_1$
# 2. Main Hypothesis

# %% [markdown]
# ### 1.3 Null vs Alternate Hypothesis

# %% [markdown]
# #### Definition

# %% [markdown]
# 1. Default assumption is called as Null Hypothesis and it is denoted as: $H_0$
# 2. Opposite of Default assumption is called as Alternate Hypothesis and is denoted as: $H_a$

# %% [markdown]
# #### Examples

# %% [markdown]
# ##### Examples for Null Hypothesis

# %% [markdown]
# 1. Coin is fair (not biased).
# 2. Suspect is innocent (not guilty).
# 3. Tumor is benign hence patient has no cancer.

# %% [markdown]
# ##### Examples for Alternate Hypothesis

# %% [markdown]
# 1. Coin is t biased.
# 2. Suspect is guilty.
# 3. Tumor is malignant hence patient has cancer.

# %% [markdown]
# #### How to define Null Hypothesis?

# %% [markdown]
# - Null hypothesis should be defined such that it is **possible to calculate the probability of observing data** given $H_0$ is true.
# - For example in a coin toss experiment, we can take probability of observing 3 consecutive heads in 5 toss, when we formulate $H_0$
#    as "coin is fair" as oppose to "coin is unfair", because it is not possible to calculate probability when the coin is unfair to start with.

# %% [markdown]
# #### How Assumptions are used in HT Framework?

# %% [markdown]
# Assumptions formulated in the beginning play crucial role in decision-making step of Hypothesis Testing Framework:
#
# - First step in Hypothesis Testing Framework is to define the two types of Assumptions:
#   - Default Assumption $H_0$
#   - Alternate Assumption $H_a$
# - End of Hypothesis Testing will have either one of the below two outcomes:
#   1. Successfully reject $H_0$ or accept $H_a$
#   2. Successfully reject $H_a$ or failed to reject $H_0$

# %% [markdown]
# #### Properties

# %% [markdown]
# 1. There is no term or process to **accept Null Hypothesis**. Null Hypothesis is **de facto** and is already accepted.
# 2. Gather evidence towards the claim to either **reject Null Hypothesis** or **failed to reject Null Hypothesis**.
# 3. Gather evidence towards the claim to either **accept Alternate Hypothesis** or **reject Alternate Hypothesis**.

# %% [markdown]
# ### 1.4 p-value

# %% [markdown]
# #### Definition

# %% [markdown]
# $\text{p-value}$ is the **probability of observing data** as extreme as what was observed given that the Null Hypothesis **$H_0$ is true**.

# %% [markdown]
# #### Equation

# %% [markdown]
# Mathematical representation of $\text{p-value}$:
#
# $$
# \large
# \begin{aligned}
# \text{p-value} = P(\text{data} \mid H_0\;\text{is true})
# \end{aligned}
# $$

# %% [markdown]
# #### Properties

# %% [markdown]
# - $\text{p-value}$ is the metric used in the decision-making step of Hypothesis Testing Framework.
# - $\text{p-value}$ is a probability value ranging between 0 and 1.
# - $\text{p-value}$ is probability of all events which are more extreme than the given event that we are trying to analyze.
# - $\text{p-value}$ is not probability of $H_0$ or $H_a$ i.e., $\text{p-value}$ does not directly measure the probability that $H_0$ is True.

# %% [markdown]
# #### How p-value is used in HT Framework?

# %% [markdown]
# - Since $\text{p-value}$ emphasizes on $H_0$ being True to start with, lower the $\text{p-value}$ lower will be the chances of $H_0$ being true.
# - Smaller the $\text{p-value}$ higher is the confidence in our claim (Alternate Hypothesis $H_a$).
# - We reject $H_0$ when $\text{p-value}$ is very low.
# - Threshold for "very low" depends on the problem statement.
#
# $$
# \large
# \begin{aligned}
# \text{p-value}\,\downarrow&\quad\implies\quad\text{Evidence supporting}\,H_0\,\downarrow \\[5pt]
#                           &\qquad\text{or}                                               \\[5pt]
# \text{p-value}\,\downarrow&\quad\implies\quad\text{Evidence supporting}\,H_a\,\uparrow
# \end{aligned}
# $$

# %% [markdown]
# #### Example

# %% [markdown]
# Say we are convicting a suspect for murder, we start by formulating the Null Hypothesis $H_0$.

# %% [markdown]
# ##### **STEP #1**: Formulate Null and Alternate Hypothesis

# %% [markdown]
# - $H_0$ : Suspect is innocent (not guilty)
# - $H_a$ : Suspect is guilty of murder

# %% [markdown]
# ##### **STEP #2**: Collect Evidences

# %% [markdown]
# - **Evidence #1**: Suspect has a knife in his pocket
# - **Evidence #2**: Knife has blood stains
# - **Evidence #3**: Blood stains matches with the victim
# - **Evidence #4**: Fingerprint matches with the suspect
# - **Evidence #5**: CCTV caught the suspect killing the victim

# %% [markdown]
# ##### **STEP #3**: Calculate p-value

# %% [markdown]
# Metric $\text{p-value}$ is the sum of probability of all the evidences.

# %% [markdown]
# ##### **STEP #4**: Decision

# %% [markdown]
# - **Probability** of seeing so many evidences given that the suspect is innocent will be **very low**.
# - With every evidence probability of $H_0$ being true (suspect being innocent) reduces, resulting in a very low $\text{p-value}$.
# - Since the $\text{p-value}$ is very low, reject the Null Hypothesis $H_0$ i.e., reject the hypothesis that suspect is innocent.
# - In other words, accept the Alternate Hypothesis $H_a$ that the suspect is guilty of murder.

# %% [markdown]
# ### 1.5 Significance level and Confidence level

# %% [markdown]
# #### Definition

# %% [markdown]
# Significance level ($\alpha$) is the threshold value for $\text{p-value}$ used during the decision-making step of the Hypothesis Testing Framework.

# %% [markdown]
# #### Formula

# %% [markdown]
# Relationship between Significance level and Confidence level:
#
# $$
# \large
# \begin{aligned}
# \text{Significance level} &= 1 - \text{Confidence level} \\[5pt]
#                           & \text{or} \\[5pt]
#  \text{Confidence level}  &= 1 - \text{Significance level}
# \end{aligned}
# $$

# %% [markdown]
# #### Properties

# %% [markdown]
# 1. Significance level is decided based on Confidence level.
# 2. Confidence level indicates how confident are we on the gathered evidence/data.
# 3. Value for Significance level can range between 0 and 1.

# %% [markdown]
# #### How Significance Level is used in HT Framework?

# %% [markdown]
# - Significance level or threshold value is used in the decision-making step of HT Framework.
# - Significance level is part of if-else condition in the decision-making step of HT Framework.
#
# $$
# \large
# \begin{aligned}
# &\text{if p-value} \le \alpha \text{:}                       \\[3pt]
# &\quad\quad \text{Reject $H_0$ i.e., Accept $H_a$}           \\[6pt]
# &\text{else:}                                                \\[3pt]
# &\quad\quad \text{Failed to reject $H_0$ i.e., Reject $H_a$}
# \end{aligned}
# $$
#
# Where,
#
# - $\alpha$ is called as **Significance level**
# - $1 - \alpha$ is called as **Confidence level**

# %% [markdown]
# #### How to decide the threshold value?

# %% [markdown]
# 1. Threshold value is selected in such a way that **chances of error** is less.
# 2. Threshold value $\alpha$ depends on the **domain** of the problem.
# 3. For example medical domain can have very low threshold of 0.01 or 1%.
# 4. Generally the value of $\alpha$ must be less than 0.05 or 5%.

# %% [markdown]
# > **Note**:
# >
# > Generally in most of the industries 95% confidence level is considered hence most
# > common value for Confidence Level is 0.95, therefore Significance Level is 0.05.

# %% [markdown]
# #### Risks involved in Significance level

# %% [markdown]
# - Setting a Significance level while taking a decision often involves some risk (or results in errors).
# - There can be errors when calculating the $\text{p-value}$, which affects in the decision making.

# %% [markdown]
# Risk can be illustrated using a confusion matrix:
#
# ```
#                       Actual
#                    0         1
#              +----------+----------+
#            0 | No Error |  Error   |
# Predicted    +----------+----------+
#            1 |  Error   | No Error |
#              +----------+----------+
# ```
#
# In the above diagram,
#
# 1. Its declared _No Error_ when the Actual and the Predicted values **are same**.
# 2. Its declared _Error_ when the Actual and the Predicted values **are different**.

# %% [markdown]
# ## 2 Types of Errors

# %% [markdown]
# ### 2.1 Confusion Matrix

# %% [markdown]
# #### Metrics

# %% [markdown]
# Confusion Matrix has four metrics:
#
# 1. True Negative
# 2. False Negative
# 3. True Positive
# 4. False positive
#
# ```
#                            Actual
#                       0                1
#              +----------------+----------------+
#            0 | True Negative  | False Negative |
# Predicted    +----------------+----------------+
#            1 | False Positive | True Positive  |
#              +----------------+----------------+
# ```

# %% [markdown]
# #### Convention

# %% [markdown]
# By convention, labeling style for Confusion Matrix follows:
#
# 1. Label "_Actual_" should be on top of the Confusion Matrix.
# 2. Label "_Predicted_" should be towards the left of Confusion Matrix.

# %% [markdown]
# #### How Confusion Matrix is used in HT Framework?

# %% [markdown]
# - Above if-else condition used in the decision-making step of HT framework is **prone to errors** and needs validation.
# - Confusion Matrix is used to **capture the errors** that can occur during decision-making step of HT framework.
# - Confusion Matrix just captures the errors and does not reduce the errors.

# %% [markdown]
# #### Mapping Confusion Matrix with Types-of-Errors

# %% [markdown]
# ```
#                          Actual
#                     0              1
#              +--------------+--------------+
#            0 |   No Error   | Type-2 Error |
# Predicted    +--------------+--------------+
#            1 | Type-1 Error |   No Error   |
#              +--------------+--------------+
# ```
#
# As seen in the above confusion matrix there are two types of errors:
#
# 1. False Positive in Confusion Matrix is mapped to **Type 1 Error** $(\alpha)$ a.k.a Significance level.
# 2. False Negative in Confusion Matrix is mapped to **Type 2 Error** $(\beta)$

# %% [markdown]
# ### 2.2 CM in HT Framework

# %% [markdown]
# Application of Confusion Matrix in Hypothesis Testing Framework can be better understood with an example.

# %% [markdown]
# #### Example #1: Court Judgement

# %% [markdown]
# Given below,
#
# - $H_0 : \text{Person is Innocent (not Guilty)}$
# - $H_a : \text{Person is Guilty}$

# %% [markdown]
# In the hypothesis testing framework, a confusion matrix is primarily a way to categorize decision outcomes and decision errors.

# %% [markdown]
# ```
#                                                  Actually
#                                       Innocent (-)      Guilty (+)
#                                    +----------------+----------------+
#                       Innocent (-) | True Negative  | False Negative |
#           Judge said               +----------------+----------------+
#                         Guilty (+) | False Positive | True Positive  |
#                                    +----------------+----------------+
# ```

# %% [markdown]
# ```
#                                              H_0 is Actually
#                                         True (-)         False (+)
#                                    +----------------+----------------+
#           Failed to reject H_0 (-) | True Negative  | False Negative |
# Decision                           +----------------+----------------+
#                   Rejected H_0 (+) | False Positive | True Positive  |
#                                    +----------------+----------------+
# ```

# %% [markdown]
# 1. Type-1 Error occurs in above example on rejecting $H_0$ when it is actually True.
# 2. Type-2 Error occurs in above example on failing to reject $H_0$ when it is actually False.

# %% [markdown]
# #### CM Metrics vs Errors vs Symbols vs HT

# %% [markdown]
# <div style="display: inline-block">
#
# | Metric in CM   | Error  |  Symbol  | Decision                                  | Interpretation in Hypothesis Testing            |
# | :------------- | :----- | :------: | :---------------------------------------- | :---------------------------------------------- |
# | False Positive | Type-1 | $\alpha$ | Rejecting $H_0$ when it is actually True. | Incorrect rejection of a True Null Hypothesis.  |
# | False Negative | Type-2 | $\beta$  | Rejecting $H_a$ when it is actually True. | Failing to reject an incorrect Null Hypothesis. |
#
# </div>

# %% [markdown]
# #### How to define hypotheses?

# %% [markdown]
# 1. $H_0$ is the status quo and is often considered Negative i.e., **absence of something** for example: Benign (absence of cancer), not guilty, etc.
# 2. $H_a$ claims the **presence of something** hence considered Positive, for example: Malignant (presence of cancer), guilty, etc.

# %% [markdown]
# #### Type-1 error vs Type-2 error

# %% [markdown]
# **Q**: Between Type-1 and Type-2 errors which one should be low?
#
# **Ans**:
# This depends on the domain. For example:
#
# 1. **Judicial** process should have **very low Type-1 error** because an innocent should not be punished for the crime that they didn't commit.
# 2. **Medical** diagnostic should have **very low Type-2 error** because a disease should not go undetected, additional tests can be performed to reaffirm.

# %% [markdown]
# #### Summary on Types-of-Errors

# %% [markdown]
# <div style="display: inline-block">
#
# |                                      | Type-1 Error                 | Type-2 Error                     |
# | :----------------------------------- | :--------------------------- | :------------------------------- |
# | Symbol                               | Alpha $\alpha$               | Beta $\beta$                     |
# | Metric in Confusion Matrix           | False Positive               | False Negative                   |
# | Interpretation in Hypothesis Testing | Incorrect rejection of $H_0$ | Failed to reject incorrect $H_0$ |
#
# </div>

# %% [markdown]
# ### 2.3 Power of test

# %% [markdown]
# In a Machine learning system the goal is to **reduce both Type-1 and Type-2 errors**.

# %% [markdown]
# #### Definition

# %% [markdown]
# 1. Power represents the probability of correctly rejecting a False Null Hypothesis.
# 2. $1 - \beta$ (True Positive) is also called as **Power of test**.
#
# ```
#                         Actual
#                     0           1
#              +------------+------------+
#            0 | 1 - α (TN) |     β (FN) |
# Predicted    +------------+------------+
#            1 |     α (FP) | 1 - β (TP) |
#              +------------+------------+
# ```

# %% [markdown]
# The goal of power of test is to reduce Type-2 error $(\beta)$.
#
# $$
# \large
# \begin{aligned}
# \text{FN} \;+\; \quad\;\;\,\text{TP} = 1 \\[5pt]
# \beta     \;+\;        (1 - \beta) = 1
# \end{aligned}
# $$
#
# 1. To reduce Type-2 error $\beta$ (False Negative) we have to increase $1 - \beta$ (True Positive).
# 2. To reduce Type-1 error $\alpha$ (False Positive) we have to increase $1 - \alpha$ (True Negative).

# %% [markdown]
# > **Note**:
# >
# > To increase Power of test $(1 - \beta)$ we have to reduce $\beta$.

# %% [markdown]
# #### Relationship between Alpha and Beta

# %% [markdown]
# $$
# \large
# \begin{aligned}
# \alpha = \frac{1}{\beta}
# \end{aligned}
# $$
#
# Since $\alpha$ and $\beta$ are inversely proportional to each other, mathematically it is not possible to reduce both the errors at the same time.
# We always need to find a trade off  between $\alpha$ and $\beta$.

# %% [markdown]
# #### Factors influencing Power

# %% [markdown]
# 1. Sample size $(n)$: As sample size increases power increases.
# 2. Significance level $(\alpha)$: As Significance level increases beta reduces (hence power increases).
# 3. Variance $(\sigma)$: As Variance increases Type-2 error increases (hence power reduces).
# 4. Effect Size $(d)$: As effect size increases power increases.

# %% [markdown]
# #### Complete Summary

# %% [markdown]
# <div style="display: inline-block">
#
# |   # | Metric in CM   |       Symbol | Representation     | Error Type   | Interpretation in Hypothesis Testing                    |
# | --: | :------------- | -----------: | :----------------- | :----------- | :------------------------------------------------------ |
# |   1 | True Negative  | $1 - \alpha$ | Confidence level   |              | Correctly failing to reject a true Null Hypothesis.     |
# |   2 | False Negative |      $\beta$ |                    | Type-2 Error | Failing to reject an incorrect (false) Null Hypothesis. |
# |   3 | True Positive  |  $1 - \beta$ | Power of Test      |              | Correctly rejecting a false Null Hypothesis.            |
# |   4 | False Positive |     $\alpha$ | Significance level | Type-1 Error | Incorrect rejection of a true Null Hypothesis.          |
#
# </div>

# %% [markdown]
# ## 3 Tailed Test

# %% [markdown]
# ### 3.1 Test Statistic

# %% [markdown]
# #### What is a Test Statistic?

# %% [markdown]
# A Sample-statistic computed from sample data that quantifies how much the observed sample differs from the null hypothesis.

# %% [markdown]
# Overall there will be three distributions:
#
# 1. Population Distribution: Distribution of a Random variable For example: $X$.
# 2. Sampling Distribution: Distribution of a sample statistic. For example: $\bar{X}$ (distribution of sample means).
# 3. Reference Distribution: Distribution of chosen Test Statistic. For example $Z$ (Z-Statistic).

# %% [markdown]
# #### Relationship

# %% [markdown]
# $$
# \large
# \text{Population}\,\rightarrow\,\text{Sample}\,\rightarrow\,\text{Sample Statistic}\,\rightarrow\,\text{Test Statistic}\,\rightarrow\,\text{Reference Distribution}
# $$

# %% [markdown]
# ### 3.2 Reference Distribution

# %% [markdown]
# #### Definition

# %% [markdown]
# $$
# \large
# \text{Reference Distribution} = \text{Distribution of Test Statistic} \mid H_0\;\text{is true}
# $$

# %% [markdown]
# Reference Distribution is the Sampling distribution of a test statistic under the assumption that the Null Hypothesis $H_0$ is true.

# %% [markdown]
# ![Reference Distribution](images/ref_dist.png)

# %% [markdown]
# #### Properties

# %% [markdown]
# - Reference distribution tells us, if $H_0$ is true then what values of the test statistic are likely and unlikely.
# - Reference distribution acts as a **benchmark** while taking decisions.
# - We use the Reference Distribution to determine the critical value or $\text{p-value}$ to assess a test statistic's
#   probability of being as extreme as what was observed given that the Null Hypothesis $H_0$ is true.
# - Significance level on Reference Distribution acts as a threshold needed for taking decisions.

# %% [markdown]
# #### p-value on Reference Distribution

# %% [markdown]
# ##### How p-value is mapped on Reference Distribution?

# %% [markdown]
# ![p-value on Reference Distribution](images/ref_dist_p_value.png)

# %% [markdown]
# - $\text{p-value}$ is the **area under highlighted portion** of the curve.
# - $\text{p-value}$ is calculated using `cdf` function of the reference distribution
# - $\text{p-value}$ is calculated **after** observing the sample.

# %% [markdown]
# #### Significance-level on Reference Distribution

# %% [markdown]
# ##### How Significance-level is mapped on Reference Distribution?

# %% [markdown]
# ![Significance Level on Reference Distribution](images/ref_dist_significance_level.png)

# %% [markdown]
# - Significance-level is the **area under highlighted portion** of the curve.
# - Significance-level is **fixed tail area** under the reference distribution.
# - Significance-level is chosen **before** seeing the data.

# %% [markdown]
# #### Application of Reference Distribution in HT

# %% [markdown]
# Decision process in Hypothesis Testing using Reference Distribution and Significance level for the computed $\text{p-value}$ is shown below:

# %% [markdown]
# ![Significance Level on Reference Distribution](images/ref_dist_alpha_and_p_value.png)

# %% [markdown]
# ### 3.3 Types of Tailed Tests

# %% [markdown]
# There are two primary types of tests:
#
# 1. One Tailed Test (Directional Test)
#     1. Left Tailed Test
#     2. Right Tailed test
# 2. Two Tailed test (Non-directional Test)

# %% [markdown]
# #### How to identify the right type of test?

# %% [markdown]
# Alternate Hypothesis $H_a$ helps decide the type of tailed test:
#
# 1. if the condition in $H_a$ is $<$ or $\le$ then perform **Left-Tailed** test.
# 2. if the condition in $H_a$ is $>$ or $\ge$ then perform **Right-Tailed** test.
# 3. if the condition in $H_a$ is $\ne$ then perform **Two-Tailed** test.

# %% [markdown]
# #### Conventions

# %% [markdown]
# Conventions followed while formulating Hypotheses:
#
# - Equal comparison i.e., $=$ operator should always be present in $H_0$
# - $H_0$ and $H_a$ should be **mutually exclusive** and **collectively exhaustive**.

# %% [markdown]
# ## 4 Types of Tailed Tests

# %% [markdown]
# ### 4.1 Left Tailed Test

# %% [markdown]
# #### Hypotheses

# %% [markdown]
# - $H_0 : \mu \ge \text{value}$
# - $H_a : \mu \lt \text{value}$
#
# Perform Left-tailed test.

# %% [markdown]
# #### p-value Calculation

# %% [markdown]
# ![Left Tailed Test](images/tailed_test_left.png)

# %% [markdown]
# - Probability ($\text{p-value}$) is calculated using `cdf()` of the reference distribution.
# - Highlighted area under the curve in the above distribution represents $\alpha$.
# - Reject $H_0$ if $\text{p-value}$ falls inside the area of $\alpha$.

# %% [markdown]
# ### 4.2 Right Tailed Test

# %% [markdown]
# #### Hypotheses

# %% [markdown]
# - $H_0 : \mu \le \text{value}$
# - $H_a : \mu \gt \text{value}$
#
# Perform Right-tailed test.

# %% [markdown]
# #### p-value Calculation

# %% [markdown]
# ![Right Tailed Test](images/tailed_test_right.png)

# %% [markdown]
# - Probability ($\text{p-value}$) is calculated using `1 - cdf()` of the reference distribution.
# - Highlighted area under the curve in the above distribution represents $\alpha$.
# - Reject $H_0$ if $\text{p-value}$ falls inside the area of $\alpha$.

# %% [markdown]
# ### 4.3 Two Tailed Test

# %% [markdown]
# #### Hypotheses

# %% [markdown]
# - $H_0 : \mu = \text{value}$
# - $H_a : \mu \ne \text{value}$
#
# Perform Two-tailed test.

# %% [markdown]
# #### p-value Calculation

# %% [markdown]
# ![Two Tailed Test](images/tailed_test_two.png)

# %% [markdown]
# - In a continuous distribution probability of a random variable $X$ taking a value $x_1$ is zero i.e., $P(X = x_1) = 0$.
# - Consequently, a random variable $X$ not taking a value $x_1$ is equal to one i.e., $P(X \ne x_1) = 1$.
# - Therefore, probabilities for continuous random variables are meaningfully computed over intervals (ranges of values) rather than at individual points.

# %% [markdown]
# #### Summary

# %% [markdown]
# <div style="display: inline-block">
#
# | Case         | Tail test type    |
# | :----------: | :---------------- |
# | $<$ or $\le$ | Left tailed test  |
# | $>$ or $\ge$ | Right tailed test |
# | $\ne$        | Two tailed test   |
#
# </div>

# %% [markdown]
# ## 5 Hypothesis Testing Framework

# %% [markdown]
# ### 5.1 Steps in Hypothesis Testing

# %% [markdown]
# - **STEP #1**: Formulate Null-Hypothesis $H_0$ and Alternate-Hypothesis $H_a$
# - **STEP #2**: Choose a Distribution, Test-statistic and Significance-level $(\alpha)$
# - **STEP #3**: Select type of test: Left / Right / Two-tailed
# - **STEP #4**: Compute $\text{p-value}$
# - **STEP #5**: Compare $\text{p-value}$ with $\alpha$, reject $H_0$ if $\text{p-value} \le \alpha$ else reject $H_a$

# %% [markdown]
# ### 5.2 Examples

# %% [markdown]
# #### Example #1: Fair coin toss

# %% [markdown]
# ##### STEP 1: Formulate Null and Alternate Hypothesis

# %% [markdown]
# - $H_0$ : Coin is fair
# - $H_a$ : Coin is biased
#
# Above formulation can be mathematically written as,
#
# - $H_0 : p = 0.5$
# - $H_a : p \ne 0.5$
#
# The coin may be bias towards Head or bias towards Tail.

# %% [markdown]
# ##### STEP 2: Choose Significance level

# %%
# Distribution: Binomial distribution
# Significance level: 0.05
alpha = 0.05

# %% [markdown]
# ##### STEP 3: Select type of test

# %% [markdown]
# Since $H_a$ has $\ne$ symbol perform two tailed test.

# %% [markdown]
# ##### STEP 4: Compute p-value

# %%
p_value = 0.001  # Dummy value for example

# %% [markdown]
# ##### STEP 5: Compare p-value with alpha

# %%
if p_value < alpha:
    print("Reject Null-Hypothesis i.e., accept Alternate-Hypothesis.")
else:
    print("Failed to reject Null-Hypothesis i.e., reject Alternate-Hypothesis.")
# Out:
# Reject Null-Hypothesis i.e., accept Alternate-Hypothesis.

# %% [markdown]
# #### Example #2: Coin toss biased toward head

# %% [markdown]
# ##### Formulate Null and Alternate Hypothesis

# %% [markdown]
# - $H_0$ : Coin is fair
# - $H_a$ : Coin is biased towards Head
#
# Above formulation can be mathematically written as,
#
# - $H_0 : P(H) = 0.5$
# - $H_a : P(H) > 0.5$
#
# Then we have to perform Right Tailed Test.
#
# or
#
# - $H_0 : P(T) = 0.5$
# - $H_a : P(T) < 0.5$
#
# Then we have to perform Left Tailed Test.

# %% [markdown]
# ### 5.3 Types of Hypothesis Testing

# %% [markdown]
# Types of Hypothesis Testing:
#
# 1. Z-test
#     1. One sample Z-test
#     2. Two sample Z-test
# 2. Z-Proportion Test
#     1. One sample Z-Proportion test
#     2. Two sample Z-Proportion test
# 3. T-test
#     1. One sample T-test
#     2. Two sample Independent T-test
#     3. Two sample Paired T-test
# 4. Chi-Squared Test
#     1. Chi-square Goodness of fit test
#     2. Chi-square Test for Independence
# 5. ANOVA
#     1. One-way ANOVA
#     2. Two-way ANOVA
# 6. Correlation Analysis

# %% [markdown]
# ## 6 Quizzes

# %% [markdown]
# ### Quiz #1

# %% [markdown]
# The juice brand claims that the mean sugar content in its juice boxes, produced using a new manufacturing process, is less than 8 grams.
# The Food Safety and Standards Authority of India (FSSAI) wants to test the null hypothesis in this scenario.
# Set up the null (H0) and alternate (H1) hypotheses for this claim, and choose the correct option:

# %% [markdown]
# 1. H0: The sugar content in the juice boxes produced using the new manufacturing process is not equal to 8 grams.
#    H1: The sugar content in the juice boxes produced using the new manufacturing process is equal to 8 grams.
# 2. H0: The sugar content in the juice boxes produced using the new manufacturing process is greater than 8 grams.
#    H1: The sugar content in the juice boxes produced using the new manufacturing process is less than 8 grams.
# 3. H0: The sugar content in the juice boxes produced using the new manufacturing process is less than 8 grams.
#    H1: The sugar content in the juice boxes produced using the new manufacturing process is greater than 8 grams.
# 4. H0: The sugar content in the juice boxes produced using the new manufacturing process is greater than or equal to 8 grams.
#    H1: The sugar content in the juice boxes produced using the new manufacturing process is less than 8 grams.

# %% [markdown]
# #### Solution

# %% [markdown]
# 4. H0: The sugar content in the juice boxes produced using the new manufacturing process is greater than or equal to 8 grams.
#    H1: The sugar content in the juice boxes produced using the new manufacturing process is less than 8 grams.

# %% [markdown]
# ### Quiz #2

# %% [markdown]
# Local people claim that the river water quality is good.
# An environmental agency wants to test their claim. Upon testing, they obtained a p-value of 0.001.
# The significance level ($\alpha$) is set at 0.05.
#
# What is the appropriate conclusion?
#
# 1. Reject the null hypothesis
# 2. Fail to reject the null hypothesis
# 3. Increase the significance level
# 4. Conduct additional tests

# %% [markdown]
# #### Solution

# %% [markdown]
# 1. Reject the null hypothesis

# %% [markdown]
# ### Quiz #3

# %% [markdown]
# A restaurant says that its new menu item has a mean waiting time of less than equal to 10 minutes.
# You claim that the mean wait time is greater than 10 minutes.
# What should be the null and alternate hypotheses to test their claim?
#
# 1. $H_0: \mu \le 10 \text{ and } H_a: \mu > 10$
# 1. $H_0: \mu = 10 \text{ and } H_a: \mu > 10$
# 1. $H_0: \mu = 10 \text{ and } H_a: \mu \ne 10$
# 1. $H_0: \mu \gt 10 \text{ and } H_a: \mu \le 10$

# %% [markdown]
# #### Solution

# %% [markdown]
# 1. $H_0: \mu \le 10 \text{ and } H_a: \mu > 10$

# %% [markdown]
# ### Quiz #4

# %% [markdown]
# A security system is designed to detect intruders in a restricted area.
# The null hypothesis (H0) is that there is no intruder, and the alternate hypothesis (H1) is that there is an intruder.
#
# What is a Type II error in this context?
#
# A. Detecting an intruder when there isn't one.
# B. Failing to detect an intruder when there is one.
# C. Accepting that there is no intruder when there isn't one.
# D. Rejecting the idea of an intruder when there is one.

# %% [markdown]
# #### Solution

# %% [markdown]
# B. Failing to detect an intruder when there is one.

# %% [markdown]
# ### Quiz #5

# %% [markdown]
# A pharmaceutical company is testing whether a new drug reduces blood pressure more effectively than the current standard.
#
# - The null hypothesis assumes no improvement.
# - The alternative claims a 5 mmHg improvement.
#
# The significance level is set at 0.05, and the power of the test is 0.92.
# What does this tell us?
#
# Choose the correct answer from below, please note that this question may have multiple correct answers
#
# 1. There's an 8% chance of a Type 1 error
# 2. The probability of accepting a false null is 8%
# 3. The test has a 92% chance of detecting a false null
# 4. The test has a 92% chance of making a Type I error

# %% [markdown]
# #### Solution

# %% [markdown]
# Correct options:
#
# - 2. "probability of accepting a false null" is Type-2 error and Type-2 error is 8%
# - 3. probability of "detecting a false null" is Power of test and Power is 92%
#
# Why below options are incorrect:
#
# - 1. Significance level is 0.05 or 5% hence Type-1 error is 5% and not 8%
# - 4. Type 1 error is 5% hence option 4 is wrong.

# %% [markdown]
# ## 7 Appendix

# %% [markdown]
# ### 7.1 Terminologies

# %% [markdown]
# 1. Hypothesis:
#    - $H_0$ - Null Hypothesis
#    - $H_a$ - Alternate Hypothesis
# 2. $\text{p-value} = P(\text{data} \mid H_0\;\text{is true})$
# 3. Threshold value $\alpha$ (Significance level)
# 4. $\text{Confidence level} = 1 - \text{Significance level}$

# %% [markdown]
# ### 7.2 Confusion Matrix

# %% [markdown]
# Metrics in Confusion Matrix:
#
# ```
#                             Actual
#                       0                1
#              +----------------+----------------+
#            0 | True Negative  | False Negative |
# Predicted    +----------------+----------------+
#            1 | False Positive | True Positive  |
#              +----------------+----------------+
# ```

# %% [markdown]
# ### 7.3 Types of Errors

# %% [markdown]
# Errors:
#
# ```
#                          Actual
#                     0              1
#              +--------------+--------------+
#            0 |   No Error   | Type-2 Error |
# Predicted    +--------------+--------------+
#            1 | Type-1 Error |   No Error   |
#              +--------------+--------------+
# ```

# %% [markdown]
# ### 7.4 Symbols

# %% [markdown]
# <div style="display: inline-block">
#
# |       Symbol | Names                                  |
# | -----------: | :------------------------------------- |
# |     $\alpha$ | Significance level / Type-1 Error rate |
# | $1 - \alpha$ | Confidence level                       |
# |      $\beta$ | Type-2 Error rate                      |
# |  $1 - \beta$ | Power of test                          |
#
# </div>

# %% [markdown]
# <div style="display: inline-block">
#
# |                                      | Type-1 Error                 | Type-2 Error                     |
# | :----------------------------------- | :--------------------------- | :------------------------------- |
# | Symbol                               | Alpha $\alpha$               | Beta $\beta$                     |
# | Metric in Confusion Matrix           | False Positive               | False Negative                   |
# | Interpretation in Hypothesis Testing | Incorrect rejection of $H_0$ | Failed to reject incorrect $H_0$ |
#
# </div>

# %% [markdown]
# ### 7.5 Metrics vs Symbols vs Errors vs HT

# %% [markdown]
# <div style="display: inline-block">
#
# |   # | CM Metric      |       Symbol | Representation     | Error Type   | Interpretation strictly w.r.t $H_0$                     |
# | --: | :------------- | -----------: | :----------------- | :----------- | :------------------------------------------------------ |
# |   1 | True Negative  | $1 - \alpha$ | Confidence level   |              | Correctly failing to reject a true Null Hypothesis.     |
# |   2 | False Negative |      $\beta$ |                    | Type-2 Error | Failing to reject an incorrect (false) Null Hypothesis. |
# |   3 | True Positive  |  $1 - \beta$ | Power of Test      |              | Correctly rejecting a false Null Hypothesis.            |
# |   4 | False Positive |     $\alpha$ | Significance level | Type-1 Error | Incorrect rejection of a true Null Hypothesis.          |
#
# </div>

# %% [markdown]
# ### 7.6 Types of Tailed test

# %% [markdown]
# <div style="display: inline-block">
#
# | Case         | Tail test type    |
# | :----------: | :---------------- |
# | $<$ or $\le$ | Left tailed test  |
# | $>$ or $\ge$ | Right tailed test |
# | $\ne$        | Two tailed test   |
#
# </div>

# %% [markdown]
# ### 7.7 Hypothesis Testing Framework

# %% [markdown]
# - **STEP #1**: Setup Null-Hypothesis $H_0$ and Alternate-Hypothesis $H_a$
# - **STEP #2**: Choose a Distribution, Test-statistic and Significance-level $(\alpha)$
# - **STEP #3**: Select type of test: Left / Right / Two-tailed
# - **STEP #4**: Compute $\text{p-value}$
# - **STEP #5**: Compare $\text{p-value}$ with $\alpha$, reject $H_0$ if $\text{p-value} < \alpha$ else reject $H_a$
