# %% [markdown]
# # Types of Tailed Tests

# %% [markdown]
# ![Left Tailed Test](images/tailed_test_left_with_details.png)

# %% [markdown]
# ![Right Tailed Test](images/tailed_test_right_with_details.png)

# %% [markdown]
# ![Two Tailed Test](images/tailed_test_two_with_details.png)

# %% [markdown]
# > **Note**:
# >
# > These Images are generated by ChatGPT, using below prompts.

# %% [markdown]
# ### Image Prompts

# %% [markdown]
# #### Prompt for Left Tailed Test

# %% [markdown]
# Generate an image clearly demonstrating p-value and significance-level on Reference Distribution for Left tailed test.
# Correctly label X-axis and Y-Axis.

# %% [markdown]
# #### Prompt for Right Tailed Test

# %% [markdown]
# Generate a image clearly demonstrating p-value and significance-level on Reference Distribution for right tailed test.
# Correctly label X-axis and Y-Axis.

# %% [markdown]
# #### Prompt for Two Tailed Test

# %% [markdown]
# Generate an image clearly demonstrating p-value and significance-level on Reference Distribution for Two tailed test.
# Correctly label X-axis and Y-Axis.
